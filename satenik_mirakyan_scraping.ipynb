# %% [markdown]
# 1. For each movie you need to scrape:
# Title = The Shawshank Redemption (6.25 points)
# Rank of the movie from top 250 = 1 (6.25 points)
# Year = 1994 (6.25 points)
# Duration = 2h 22m (6.25 points)
# Age rating (pg13, R etc.) = R (6.25 points)
# Star rating = 9.3 (6.25 points)
# Number of voters = 3M (6.25 points)
# 2. In the end create a dataframe with all the values and save it as a csv. (6.25 points

# %%
from bs4 import BeautifulSoup
import requests

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Safari/537.36"
}

url = "https://www.imdb.com/chart/top/?ref_=nv_mv_250"
resp = requests.get(url, headers=headers)
print(resp.status_code)
# Out:
# 200

# %%
a = []
for i in range(1, len(soup.find_all("span", class_="sc-5bc66c50-6 OOdsw cli-title-metadata-item")),3):
  a.append(soup.find_all("span", class_="sc-5bc66c50-6 OOdsw cli-title-metadata-item")[i].text)


a
# Out:
# ['2h 22m',
#  '2h 55m',
#  '2h 32m',
#  '3h 22m',
#  '1h 36m',
#  '3h 21m',
#  '3h 15m',
#  '2h 34m',
#  '2h 58m',
#  '2h 41m',
#  '2h 22m',
#  '2h 59m',
#  '2h 19m',
#  '2h 28m',
#  '2h 4m',
#  '2h 16m',
#  '2h 25m',
#  '2h 13m',
#  '2h 49m',
#  '2h 7m',
#  '2h 10m',
#  '3h 27m',
#  '1h 58m',
#  '2h 49m',
#  '2h 10m']

# %%
title = []
for i in soup.find_all("h3", class_="ipc-title__text")[1:]:
  title.append(i.text)
title
# Out:
# ['1. 刺激1995',
#  '2. 教父',
#  '3. 黑暗騎士',
#  '4. 教父Ⅱ',
#  '5. 十二怒漢',
#  '6. 魔戒三部曲：王者再臨',
#  '7. 辛德勒的名單',
#  '8. 黑色追緝令',
#  '9. 魔戒首部曲：魔戒現身',
#  '10. 黃昏三鏢客',
#  '11. 阿甘正傳',
#  '12. 魔戒二部曲：雙城奇謀',
#  '13. 鬥陣俱樂部',
#  '14. 全面啟動',
#  '15. 星際大戰五部曲：帝國大反擊',
#  '16. 駭客任務',
#  '17. 四海好傢伙',
#  '18. 飛越杜鵑窩',
#  '19. 星際效應',
#  '20. 火線追緝令',
#  '21. 風雲人物',
#  '22. 七武士',
#  '23. 沉默的羔羊',
#  '24. 搶救雷恩大兵',
#  '25. 無法無天',
#  'Recently viewed']

# %%
year = []
for i in soup.find_all("span", class_="sc-5bc66c50-6 OOdsw cli-title-metadata-item")[1:]:
  year.append(i.text)
year
# Out:
# ['2h 22m',
#  '12+',
#  '1972',
#  '2h 55m',
#  '18+',
#  '2008',
#  '2h 32m',
#  '6+',
#  '1974',
#  '3h 22m',
#  '18+',
#  '1957',
#  '1h 36m',
#  'U',
#  '2003',
#  '3h 21m',
#  '6+',
#  '1993',
#  '3h 15m',
#  'R-15',
#  '1994',
#  '2h 34m',
#  '18+',
#  '2001',
#  '2h 58m',
#  '6+',
#  '1966',
#  '2h 41m',
#  'R',
#  '1994',
#  '2h 22m',
#  '6+',
#  '2002',
#  '2h 59m',
#  '6+',
#  '1999',
#  '2h 19m',
#  'R-18',
#  '2010',
#  '2h 28m',
#  '6+',
#  '1980',
#  '2h 4m',
#  'PG',
#  '1999',
#  '2h 16m',
#  'PG-12',
#  '1990',
#  '2h 25m',
#  'R-15',
#  '1975',
#  '2h 13m',
#  '6+',
#  '2014',
#  '2h 49m',
#  '6+',
#  '1995',
#  '2h 7m',
#  'R',
#  '1946',
#  '2h 10m',
#  '0+',
#  '1954',
#  '3h 27m',
#  'Not Rated',
#  '1991',
#  '1h 58m',
#  'R',
#  '1998',
#  '2h 49m',
#  'GP',
#  '2002',
#  '2h 10m',
#  '18+']

# %%
star = []
for i in soup.find_all("span",class_="ipc-rating-star--rating")[1:]:
  star.append(i.text)
star
# Out:
# ['9.2',
#  '9.0',
#  '9.0',
#  '9.0',
#  '9.0',
#  '9.0',
#  '8.9',
#  '8.9',
#  '8.8',
#  '8.8',
#  '8.8',
#  '8.8',
#  '8.8',
#  '8.7',
#  '8.7',
#  '8.7',
#  '8.7',
#  '8.7',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6']

# %%
voters = []
for i in soup.find_all("span", class_="ipc-rating-star--voteCount")[1:]:
  voters.append(i.text)


voters
# Out:
# ['\xa0(2.1M)',
#  '\xa0(2.9M)',
#  '\xa0(1.4M)',
#  '\xa0(894K)',
#  '\xa0(2M)',
#  '\xa0(1.5M)',
#  '\xa0(2.3M)',
#  '\xa0(2.1M)',
#  '\xa0(831K)',
#  '\xa0(2.3M)',
#  '\xa0(1.8M)',
#  '\xa0(2.4M)',
#  '\xa0(2.6M)',
#  '\xa0(1.4M)',
#  '\xa0(2.1M)',
#  '\xa0(1.3M)',
#  '\xa0(1.1M)',
#  '\xa0(2.2M)',
#  '\xa0(1.9M)',
#  '\xa0(510K)',
#  '\xa0(376K)',
#  '\xa0(1.6M)',
#  '\xa0(1.5M)',
#  '\xa0(819K)']

# %%
directors = []
for i in soup.find_all("span",class_="ipc-metadata-list-item__list-content-item ipc-metadata-list-item__list-content-item--link")[1:]:
  directors.append(i.text)
directors
# Out:
# []

# %% [markdown]
# # **<font color='red'> Title is done (6.25) ,year not cleaned(5), duration is done (6.25), star ratiing is done (6.25), number of voters not cleaned (5)</font>**
